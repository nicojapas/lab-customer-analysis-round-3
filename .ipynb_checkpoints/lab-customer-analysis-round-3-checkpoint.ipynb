# %% [markdown]
# # Lab | Customer Analysis Round 3
#
# For this lab, we still keep using the `marketing_customer_analysis.csv` file. You can find the file in the `files_for_lab` folder.
#
# ### Get the data
#
# - Use the same jupyter file from the last lab, `Customer Analysis Round 3`
#
# ### EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:
#
# 1. Show DataFrame info.
# 2. Describe DataFrame.
# 3. Show a plot of the total number of responses.
# 4. Show a plot of the response rate by the sales channel.
# 5. Show a plot of the response rate by the total claim amount.
# 6. Show a plot of the response rate by income.

# %%
import pandas as pd
import numpy as np
import random as random
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
file1 = pd.read_csv('files_for_lab/csv_files/marketing_customer_analysis.csv')
data = pd.DataFrame(file1)

# %%
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
data.columns = data.columns.str.replace(" ","_").str.lower()
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %% [markdown]
# 1. Show DataFrame info.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   object
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
# ...

# %% [markdown]
# 2. Describe DataFrame.

# %%
# Describes numericals
data.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
# Describes categoricals
data.describe(include=object)
# Out:
#        customer       state response coverage education effective_to_date  \
# count      9134        9134     9134     9134      9134              9134
# unique     9134           5        2        3         5                59
# top     LE85123  California       No    Basic  Bachelor           1/10/11
# freq          1        3150     7826     5568      2748               195
#
#        employmentstatus gender location_code marital_status    policy_type  \
# count              9134   9134          9134           9134           9134
# unique                5      2             3              3              3
# top            Employed      F      Suburban        Married  Personal Auto
# freq               5698   4658          5779           5298           6788
#
#              policy renew_offer_type sales_channel  vehicle_class vehicle_size
# count          9134             9134          9134           9134         9134
# ...

# %% [markdown]
# 3. Show a plot of the total number of responses.

# %%
def df_countplot(df, x, hue, y_label):
    sns.countplot(x=x, data=df, hue=hue)
    plt.ylabel(y_label)
    plt.show()

# %%
df_countplot(data, 'response', 'sales_channel', 'Total number of responses')

# %%
# Below a different way

# %%
plot_y = [data['response'].value_counts().No, data['response'].value_counts().Yes]
plt.bar(data['response'].unique(), plot_y, color=['green', 'red'])
plt.show()

# %% [markdown]
# 4. Show a plot of the response rate by the sales channel.

# %%
# One way showing percentages

# %%
response_no = []
response_yes = []
labels = []

def response_by_channel(x,y):
    for i in y.unique().tolist():
        response_total = (x[(y==i)].count())
        response_no.append(x[(y==i)].value_counts().No/response_total)
        response_yes.append(x[(y==i)].value_counts().Yes/response_total)
        labels.append(i)
        
response_by_channel(data['response'],data['sales_channel'])

# %%
x_pos = np.arange(len(labels))
WIDTH = 0.4

plt.bar(x_pos, response_no, width=WIDTH)
plt.bar(x_pos+WIDTH, response_yes, width=WIDTH)
plt.xticks(x_pos+WIDTH/2, labels)

plt.show()

# %%
# Another way showing absolute numbers

# %%
df_countplot(data, 'response', 'sales_channel', 'Number of responses by sales channel')

# %% [markdown]
# 5. Show a plot of the response rate by the total claim amount.

# %%
sns.boxplot(y='total_claim_amount', x='response', data=data)
plt.ylabel('Response by Total Claim Amount')
plt.show()

# %% [markdown]
# 6. Show a plot of the response rate by income.

# %%
sns.boxplot(y='income', x='response', data=data)
plt.ylabel('Response by Income')
plt.show()
